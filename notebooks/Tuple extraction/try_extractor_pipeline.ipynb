# %%
from pathlib import Path
import json

# 1) import the debug extractor
from hydraedge.extractor.cli import extract_sentence_debug

# 2) compute paths (assumes this notebook lives in notebooks/Tuple extraction/)
base      = Path.cwd().parent.parent
gaz_path  = base / "data" / "sample" / "syn_dict.tsv"
role_path = base / "data" / "sample" / "roles.tsv"

# sanity checks
assert gaz_path.exists(),  f"Gazetteer not found: {gaz_path}"
assert role_path.exists(), f"Roles file not found: {role_path}"

# 3) define two longer test sentences
sentences = [
    "After a decade of research and development, the startup finally unveiled its flagship quantum-secure communications platform to an audience of industry leaders and venture capitalists.",
    "While the committee debated the proposed amendments late into the night, a coalition of independent experts published a comprehensive white paper highlighting both the strengths and the potential risks of the new regulatory framework."
]

# 4) run pipeline in debug mode for each and print all stages
for sent in sentences:
    print(f"\n\n========== PROCESSING SENTENCE ==========\n{sent}\n")
    debug = extract_sentence_debug(
        sent,
        gaz_path=str(gaz_path),
        role_path=str(role_path),
    )

    for stage in ["cap", "tokens", "deps", "frames", "raw", "tuples", "hulls"]:
        print(f"\n=== {stage.upper()} ===")
        print(json.dumps(debug.get(stage, []), indent=2))

    print("\n=== FINAL PAYLOAD ===")
    print(json.dumps(debug["payload"], indent=2))
# Out:
# ========== PROCESSING SENTENCE ==========
# After a decade of research and development, the startup finally unveiled its flagship quantum-secure communications platform to an audience of industry leaders and venture capitalists.
#
#
# === CAP ===
# {
#   "text": "After a decade of research and development, the startup finally unveiled its flagship quantum-secure communications platform to an audience of industry leaders and venture capitalists.",
#   "stub": null
# }
#
# === TOKENS ===
# [
#   [
#     "After",
#     "ADP",
#     0
#   ],
#   [
#     "a",
#     "DET",
#     6
#   ],
#   [
#     "decade",
#     "NOUN",
#     8
#   ],
#   [
#     "of",
#     "ADP",
#     15
#   ],
#   [
#     "research",
#     "NOUN",
#     18
#   ],
#   [
#     "and",
#     "CCONJ",
#     27
#   ],
#   [
#     "development",
#     "NOUN",
#     31
#   ],
#   [
#     ",",
#     "PUNCT",
#     42
#   ],
#   [
#     "the",
#     "DET",
#     44
#   ],
#   [
#     "startup",
#     "NOUN",
#     48
#   ],
#   [
#     "finally",
#     "ADV",
#     56
#   ],
#   [
#     "unveiled",
#     "VERB",
#     64
#   ],
#   [
#     "its",
#     "PRON",
#     73
#   ],
#   [
#     "flagship",
#     "NOUN",
#     77
#   ],
#   [
#     "quantum",
#     "NOUN",
#     86
#   ],
#   [
#     "-",
#     "PUNCT",
#     93
#   ],
#   [
#     "secure",
#     "ADJ",
#     94
#   ],
#   [
#     "communications",
#     "NOUN",
#     101
#   ],
#   [
#     "platform",
#     "NOUN",
#     116
#   ],
#   [
#     "to",
#     "ADP",
#     125
#   ],
#   [
#     "an",
#     "DET",
#     128
#   ],
#   [
#     "audience",
#     "NOUN",
#     131
#   ],
#   [
#     "of",
#     "ADP",
#     140
#   ],
#   [
#     "industry",
#     "NOUN",
#     143
#   ],
#   [
#     "leaders",
#     "NOUN",
#     152
#   ],
#   [
#     "and",
#     "CCONJ",
#     160
#   ],
#   [
#     "venture",
#     "NOUN",
#     164
#   ],
#   [
#     "capitalists",
#     "NOUN",
#     172
#   ],
#   [
#     ".",
#     "PUNCT",
#     183
#   ]
# ]
#
# === DEPS ===
# [
#   [
#     0,
#     11,
#     "prep"
#   ],
#   [
#     1,
#     2,
#     "det"
#   ],
#   [
#     2,
#     0,
#     "pobj"
#   ],
#   [
#     3,
#     2,
#     "prep"
#   ],
#   [
#     4,
#     3,
#     "pobj"
#   ],
#   [
#     5,
#     4,
#     "cc"
#   ],
#   [
#     6,
#     4,
#     "conj"
#   ],
#   [
#     7,
#     11,
#     "punct"
#   ],
#   [
#     8,
#     9,
#     "det"
#   ],
#   [
#     9,
#     11,
#     "nsubj"
#   ],
#   [
#     10,
#     11,
#     "advmod"
#   ],
#   [
#     11,
#     11,
#     "ROOT"
#   ],
#   [
#     12,
#     18,
#     "poss"
#   ],
#   [
#     13,
#     18,
#     "nmod"
#   ],
#   [
#     14,
#     16,
#     "npadvmod"
#   ],
#   [
#     15,
#     16,
#     "punct"
#   ],
#   [
#     16,
#     18,
#     "amod"
#   ],
#   [
#     17,
#     18,
#     "compound"
#   ],
#   [
#     18,
#     11,
#     "dobj"
#   ],
#   [
#     19,
#     11,
#     "prep"
#   ],
#   [
#     20,
#     21,
#     "det"
#   ],
#   [
#     21,
#     19,
#     "pobj"
#   ],
#   [
#     22,
#     21,
#     "prep"
#   ],
#   [
#     23,
#     24,
#     "compound"
#   ],
#   [
#     24,
#     22,
#     "pobj"
#   ],
#   [
#     25,
#     24,
#     "cc"
#   ],
#   [
#     26,
#     27,
#     "compound"
#   ],
#   [
#     27,
#     24,
#     "conj"
#   ],
#   [
#     28,
#     11,
#     "punct"
#   ]
# ]
#
# === FRAMES ===
# [
#   {
#     "verb": "unveiled",
#     "verb_index": 11,
#     "words": [
#       "After",
#       "a",
#       "decade",
#       "of",
#       "research",
#       "and",
#       "development",
#       ",",
#       "the",
#       "startup",
#       "finally",
#       "unveiled",
#       "its",
#       "flagship",
#       "quantum",
#       "-",
#       "secure",
#       "communications",
#       "platform",
#       "to",
#       "an",
#       "audience",
#       "of",
#       "industry",
#       "leaders",
#       "and",
#       "venture",
#       "capitalists",
#       "."
#     ],
#     "tags": [
#       "O",
#       "O",
#       "B-TMP",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "B-ARG0",
#       "B-TMP",
#       "B-V",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "B-ARG1",
#       "I-ARG1",
#       "I-ARG1",
#       "B-ARG2",
#       "I-ARG2",
#       "I-ARG2",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O"
#     ],
#     "description": "e0[unveil]"
#   }
# ]
#
# === RAW ===
# [
#   {
#     "srl": "TMP",
#     "span": "decade",
#     "verb": "unveiled",
#     "eid": "e0"
#   },
#   {
#     "srl": "ARG0",
#     "span": "startup",
#     "verb": "unveiled",
#     "eid": "e0"
#   },
#   {
#     "srl": "TMP",
#     "span": "finally",
#     "verb": "unveiled",
#     "eid": "e0"
#   },
#   {
#     "srl": "ARG1",
#     "span": "platform",
#     "verb": "unveiled",
#     "eid": "e0"
#   },
#   {
#     "srl": "ARG2",
#     "span": "audience",
#     "verb": "unveiled",
#     "eid": "e0"
#   }
# ]
#
# === TUPLES ===
# [
#   {
#     "role": "TMP",
#     "span": "decade",
#     "eid": "e0"
#   },
#   {
#     "role": "ARG0",
#     "span": "startup",
#     "eid": "e0"
#   },
#   {
#     "role": "TMP",
#     "span": "finally",
#     "eid": "e0"
#   },
#   {
#     "role": "ARG1",
#     "span": "platform",
#     "eid": "e0"
#   },
#   {
#     "role": "ARG2",
#     "span": "audience",
#     "eid": "e0"
#   }
# ]
#
# === HULLS ===
# [
#   {
#     "eid": "e0",
#     "members": [
#       {
#         "role": "TMP",
#         "span": "decade",
#         "eid": "e0"
#       },
#       {
#         "role": "ARG0",
#         "span": "startup",
#         "eid": "e0"
#       },
#       {
#         "role": "TMP",
#         "span": "finally",
#         "eid": "e0"
#       },
#       {
#         "role": "ARG1",
#         "span": "platform",
#         "eid": "e0"
#       },
#       {
#         "role": "ARG2",
#         "span": "audience",
#         "eid": "e0"
#       }
#     ],
#     "children": []
#   }
# ]
#
# === FINAL PAYLOAD ===
# {
#   "version": "2.4",
#   "sentence": "After a decade of research and development, the startup finally unveiled its flagship quantum-secure communications platform to an audience of industry leaders and venture capitalists.",
#   "id": "04061942-e500-43eb-be58-24b6bc304084",
#   "tuples": [
#     {
#       "role": "TMP",
#       "span": "decade",
#       "eid": "e0"
#     },
#     {
#       "role": "ARG0",
#       "span": "startup",
#       "eid": "e0"
#     },
#     {
#       "role": "TMP",
#       "span": "finally",
#       "eid": "e0"
#     },
#     {
#       "role": "ARG1",
#       "span": "platform",
#       "eid": "e0"
#     },
#     {
#       "role": "ARG2",
#       "span": "audience",
#       "eid": "e0"
#     }
#   ],
#   "layouts": {
#     "hulls": [
#       {
#         "eid": "e0",
#         "members": [
#           {
#             "role": "TMP",
#             "span": "decade",
#             "eid": "e0"
#           },
#           {
#             "role": "ARG0",
#             "span": "startup",
#             "eid": "e0"
#           },
#           {
#             "role": "TMP",
#             "span": "finally",
#             "eid": "e0"
#           },
#           {
#             "role": "ARG1",
#             "span": "platform",
#             "eid": "e0"
#           },
#           {
#             "role": "ARG2",
#             "span": "audience",
#             "eid": "e0"
#           }
#         ],
#         "children": []
#       }
#     ]
#   }
# }
#
#
# ========== PROCESSING SENTENCE ==========
# While the committee debated the proposed amendments late into the night, a coalition of independent experts published a comprehensive white paper highlighting both the strengths and the potential risks of the new regulatory framework.
#
#
# === CAP ===
# {
#   "text": "While the committee debated the proposed amendments late into the night, a coalition of independent experts published a comprehensive white paper highlighting both the strengths and the potential risks of the new regulatory framework.",
#   "stub": null
# }
#
# === TOKENS ===
# [
#   [
#     "While",
#     "SCONJ",
#     0
#   ],
#   [
#     "the",
#     "DET",
#     6
#   ],
#   [
#     "committee",
#     "NOUN",
#     10
#   ],
#   [
#     "debated",
#     "VERB",
#     20
#   ],
#   [
#     "the",
#     "DET",
#     28
#   ],
#   [
#     "proposed",
#     "VERB",
#     32
#   ],
#   [
#     "amendments",
#     "NOUN",
#     41
#   ],
#   [
#     "late",
#     "ADV",
#     52
#   ],
#   [
#     "into",
#     "ADP",
#     57
#   ],
#   [
#     "the",
#     "DET",
#     62
#   ],
#   [
#     "night",
#     "NOUN",
#     66
#   ],
#   [
#     ",",
#     "PUNCT",
#     71
#   ],
#   [
#     "a",
#     "DET",
#     73
#   ],
#   [
#     "coalition",
#     "NOUN",
#     75
#   ],
#   [
#     "of",
#     "ADP",
#     85
#   ],
#   [
#     "independent",
#     "ADJ",
#     88
#   ],
#   [
#     "experts",
#     "NOUN",
#     100
#   ],
#   [
#     "published",
#     "VERB",
#     108
#   ],
#   [
#     "a",
#     "DET",
#     118
#   ],
#   [
#     "comprehensive",
#     "ADJ",
#     120
#   ],
#   [
#     "white",
#     "ADJ",
#     134
#   ],
#   [
#     "paper",
#     "NOUN",
#     140
#   ],
#   [
#     "highlighting",
#     "VERB",
#     146
#   ],
#   [
#     "both",
#     "CCONJ",
#     159
#   ],
#   [
#     "the",
#     "DET",
#     164
#   ],
#   [
#     "strengths",
#     "NOUN",
#     168
#   ],
#   [
#     "and",
#     "CCONJ",
#     178
#   ],
#   [
#     "the",
#     "DET",
#     182
#   ],
#   [
#     "potential",
#     "ADJ",
#     186
#   ],
#   [
#     "risks",
#     "NOUN",
#     196
#   ],
#   [
#     "of",
#     "ADP",
#     202
#   ],
#   [
#     "the",
#     "DET",
#     205
#   ],
#   [
#     "new",
#     "ADJ",
#     209
#   ],
#   [
#     "regulatory",
#     "ADJ",
#     213
#   ],
#   [
#     "framework",
#     "NOUN",
#     224
#   ],
#   [
#     ".",
#     "PUNCT",
#     233
#   ]
# ]
#
# === DEPS ===
# [
#   [
#     0,
#     3,
#     "mark"
#   ],
#   [
#     1,
#     2,
#     "det"
#   ],
#   [
#     2,
#     3,
#     "nsubj"
#   ],
#   [
#     3,
#     17,
#     "advcl"
#   ],
#   [
#     4,
#     6,
#     "det"
#   ],
#   [
#     5,
#     6,
#     "amod"
#   ],
#   [
#     6,
#     3,
#     "dobj"
#   ],
#   [
#     7,
#     3,
#     "advmod"
#   ],
#   [
#     8,
#     7,
#     "prep"
#   ],
#   [
#     9,
#     10,
#     "det"
#   ],
#   [
#     10,
#     8,
#     "pobj"
#   ],
#   [
#     11,
#     17,
#     "punct"
#   ],
#   [
#     12,
#     13,
#     "det"
#   ],
#   [
#     13,
#     17,
#     "nsubj"
#   ],
#   [
#     14,
#     13,
#     "prep"
#   ],
#   [
#     15,
#     16,
#     "amod"
#   ],
#   [
#     16,
#     14,
#     "pobj"
#   ],
#   [
#     17,
#     17,
#     "ROOT"
#   ],
#   [
#     18,
#     21,
#     "det"
#   ],
#   [
#     19,
#     21,
#     "amod"
#   ],
#   [
#     20,
#     21,
#     "amod"
#   ],
#   [
#     21,
#     17,
#     "dobj"
#   ],
#   [
#     22,
#     17,
#     "advcl"
#   ],
#   [
#     23,
#     25,
#     "preconj"
#   ],
#   [
#     24,
#     25,
#     "det"
#   ],
#   [
#     25,
#     22,
#     "dobj"
#   ],
#   [
#     26,
#     25,
#     "cc"
#   ],
#   [
#     27,
#     29,
#     "det"
#   ],
#   [
#     28,
#     29,
#     "amod"
#   ],
#   [
#     29,
#     25,
#     "conj"
#   ],
#   [
#     30,
#     29,
#     "prep"
#   ],
#   [
#     31,
#     34,
#     "det"
#   ],
#   [
#     32,
#     34,
#     "amod"
#   ],
#   [
#     33,
#     34,
#     "amod"
#   ],
#   [
#     34,
#     30,
#     "pobj"
#   ],
#   [
#     35,
#     17,
#     "punct"
#   ]
# ]
#
# === FRAMES ===
# [
#   {
#     "verb": "debated",
#     "verb_index": 3,
#     "words": [
#       "While",
#       "the",
#       "committee",
#       "debated",
#       "the",
#       "proposed",
#       "amendments",
#       "late",
#       "into",
#       "the",
#       "night",
#       ",",
#       "a",
#       "coalition",
#       "of",
#       "independent",
#       "experts",
#       "published",
#       "a",
#       "comprehensive",
#       "white",
#       "paper",
#       "highlighting",
#       "both",
#       "the",
#       "strengths",
#       "and",
#       "the",
#       "potential",
#       "risks",
#       "of",
#       "the",
#       "new",
#       "regulatory",
#       "framework",
#       "."
#     ],
#     "tags": [
#       "O",
#       "O",
#       "B-ARG0",
#       "B-V",
#       "O",
#       "O",
#       "B-ARG1",
#       "I-ARG1",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O"
#     ],
#     "description": "e0[debate]"
#   },
#   {
#     "verb": "proposed",
#     "verb_index": 5,
#     "words": [
#       "While",
#       "the",
#       "committee",
#       "debated",
#       "the",
#       "proposed",
#       "amendments",
#       "late",
#       "into",
#       "the",
#       "night",
#       ",",
#       "a",
#       "coalition",
#       "of",
#       "independent",
#       "experts",
#       "published",
#       "a",
#       "comprehensive",
#       "white",
#       "paper",
#       "highlighting",
#       "both",
#       "the",
#       "strengths",
#       "and",
#       "the",
#       "potential",
#       "risks",
#       "of",
#       "the",
#       "new",
#       "regulatory",
#       "framework",
#       "."
#     ],
#     "tags": [
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "B-V",
#       "B-ARG1",
#       "I-ARG1",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O"
#     ],
#     "description": "e1[propose]"
#   },
#   {
#     "verb": "published",
#     "verb_index": 17,
#     "words": [
#       "While",
#       "the",
#       "committee",
#       "debated",
#       "the",
#       "proposed",
#       "amendments",
#       "late",
#       "into",
#       "the",
#       "night",
#       ",",
#       "a",
#       "coalition",
#       "of",
#       "independent",
#       "experts",
#       "published",
#       "a",
#       "comprehensive",
#       "white",
#       "paper",
#       "highlighting",
#       "both",
#       "the",
#       "strengths",
#       "and",
#       "the",
#       "potential",
#       "risks",
#       "of",
#       "the",
#       "new",
#       "regulatory",
#       "framework",
#       "."
#     ],
#     "tags": [
#       "O",
#       "O",
#       "O",
#       "B-TMP",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "B-ARG0",
#       "O",
#       "O",
#       "O",
#       "B-V",
#       "O",
#       "O",
#       "O",
#       "O",
#       "B-ARG1",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O"
#     ],
#     "description": "e2[publish]"
#   },
#   {
#     "verb": "highlighting",
#     "verb_index": 22,
#     "words": [
#       "While",
#       "the",
#       "committee",
#       "debated",
#       "the",
#       "proposed",
#       "amendments",
#       "late",
#       "into",
#       "the",
#       "night",
#       ",",
#       "a",
#       "coalition",
#       "of",
#       "independent",
#       "experts",
#       "published",
#       "a",
#       "comprehensive",
#       "white",
#       "paper",
#       "highlighting",
#       "both",
#       "the",
#       "strengths",
#       "and",
#       "the",
#       "potential",
#       "risks",
#       "of",
#       "the",
#       "new",
#       "regulatory",
#       "framework",
#       "."
#     ],
#     "tags": [
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "B-ARG0",
#       "B-V",
#       "O",
#       "O",
#       "B-ARG1",
#       "I-ARG1",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O",
#       "O"
#     ],
#     "description": "e3[highlight]"
#   }
# ]
#
# === RAW ===
# [
#   {
#     "srl": "ARG0",
#     "span": "committee",
#     "verb": "debated",
#     "eid": "e0"
#   },
#   {
#     "srl": "ARG1",
#     "span": "amendments",
#     "verb": "debated",
#     "eid": "e0"
#   },
#   {
#     "srl": "ARG1",
#     "span": "amendments",
#     "verb": "proposed",
#     "eid": "e1"
#   },
#   {
#     "srl": "TMP",
#     "span": "debated",
#     "verb": "published",
#     "eid": "e2"
#   },
#   {
#     "srl": "ARG0",
#     "span": "coalition",
#     "verb": "published",
#     "eid": "e2"
#   },
#   {
#     "srl": "ARG1",
#     "span": "highlighting",
#     "verb": "published",
#     "eid": "e2"
#   },
#   {
#     "srl": "ARG0",
#     "span": "paper",
#     "verb": "highlighting",
#     "eid": "e3"
#   },
#   {
#     "srl": "ARG1",
#     "span": "strengths",
#     "verb": "highlighting",
#     "eid": "e3"
#   }
# ]
#
# === TUPLES ===
# [
#   {
#     "role": "ARG0",
#     "span": "committee",
#     "eid": "e0"
#   },
#   {
#     "role": "ARG1",
#     "span": "amendments",
#     "eid": "e0"
#   },
#   {
#     "role": "ARG1",
#     "span": "amendments",
#     "eid": "e1"
#   },
#   {
#     "role": "TMP",
#     "span": "debated",
#     "eid": "e2"
#   },
#   {
#     "role": "ARG0",
#     "span": "coalition",
#     "eid": "e2"
#   },
#   {
#     "role": "ARG1",
#     "span": "highlighting",
#     "eid": "e2"
#   },
#   {
#     "role": "ARG0",
#     "span": "paper",
#     "eid": "e3"
#   },
#   {
#     "role": "ARG1",
#     "span": "strengths",
#     "eid": "e3"
#   }
# ]
#
# === HULLS ===
# [
#   {
#     "eid": "e0",
#     "members": [
#       {
#         "role": "ARG0",
#         "span": "committee",
#         "eid": "e0"
#       },
#       {
#         "role": "ARG1",
#         "span": "amendments",
#         "eid": "e0"
#       }
#     ],
#     "children": []
#   },
#   {
#     "eid": "e1",
#     "members": [
#       {
#         "role": "ARG1",
#         "span": "amendments",
#         "eid": "e1"
#       }
#     ],
#     "children": []
#   },
#   {
#     "eid": "e2",
#     "members": [
#       {
#         "role": "TMP",
#         "span": "debated",
#         "eid": "e2"
#       },
#       {
#         "role": "ARG0",
#         "span": "coalition",
#         "eid": "e2"
#       },
#       {
#         "role": "ARG1",
#         "span": "highlighting",
#         "eid": "e2"
#       }
#     ],
#     "children": []
#   },
#   {
#     "eid": "e3",
#     "members": [
#       {
#         "role": "ARG0",
#         "span": "paper",
#         "eid": "e3"
#       },
#       {
#         "role": "ARG1",
#         "span": "strengths",
#         "eid": "e3"
#       }
#     ],
#     "children": []
#   }
# ]
#
# === FINAL PAYLOAD ===
# {
#   "version": "2.4",
#   "sentence": "While the committee debated the proposed amendments late into the night, a coalition of independent experts published a comprehensive white paper highlighting both the strengths and the potential risks of the new regulatory framework.",
#   "id": "b8852cb7-6941-459b-b8c0-bbbca9f2f3ff",
#   "tuples": [
#     {
#       "role": "ARG0",
#       "span": "committee",
#       "eid": "e0"
#     },
#     {
#       "role": "ARG1",
#       "span": "amendments",
#       "eid": "e0"
#     },
#     {
#       "role": "TMP",
#       "span": "debated",
#       "eid": "e2"
#     },
#     {
#       "role": "ARG0",
#       "span": "coalition",
#       "eid": "e2"
#     },
#     {
#       "role": "ARG1",
#       "span": "highlighting",
#       "eid": "e2"
#     },
#     {
#       "role": "ARG0",
#       "span": "paper",
#       "eid": "e3"
#     },
#     {
#       "role": "ARG1",
#       "span": "strengths",
#       "eid": "e3"
#     }
#   ],
#   "layouts": {
#     "hulls": [
#       {
#         "eid": "e0",
#         "members": [
#           {
#             "role": "ARG0",
#             "span": "committee",
#             "eid": "e0"
#           },
#           {
#             "role": "ARG1",
#             "span": "amendments",
#             "eid": "e0"
#           }
#         ],
#         "children": []
#       },
#       {
#         "eid": "e1",
#         "members": [
#           {
#             "role": "ARG1",
#             "span": "amendments",
#             "eid": "e1"
#           }
#         ],
#         "children": []
#       },
#       {
#         "eid": "e2",
#         "members": [
#           {
#             "role": "TMP",
#             "span": "debated",
#             "eid": "e2"
#           },
#           {
#             "role": "ARG0",
#             "span": "coalition",
#             "eid": "e2"
#           },
#           {
#             "role": "ARG1",
#             "span": "highlighting",
#             "eid": "e2"
#           }
#         ],
#         "children": []
#       },
#       {
#         "eid": "e3",
#         "members": [
#           {
#             "role": "ARG0",
#             "span": "paper",
#             "eid": "e3"
#           },
#           {
#             "role": "ARG1",
#             "span": "strengths",
#             "eid": "e3"
#           }
#         ],
#         "children": []
#       }
#     ]
#   }
# }
